# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def closest_node(node, nodes):
    nodes = np.asarray(nodes)
    dist_2 = np.sum((nodes - node)**2, axis=1)
    node = nodes[np.argmin(dist_2)]
    return (node[0],node[1])

# %%
# Object wise drawing
img = cv2.imread("images/t1.png",0)
ret, labels = cv2.connectedComponents(img)
plt.imshow(labels,'gray')

# %%
label = np.zeros_like(labels)
label[labels == 1] = 1
plt.imshow(label,'gray')

# %%
indexes = np.where(label == 1)
indexes = list(zip(indexes[0],indexes[1]))
# indexes = [(0,0),(0,1),(0,2),(1,2),(2,2),(3,1),(3,0)]
points = [indexes[0]]
while len(points) < len(indexes):
    node = points[-1]
    nodes = list(set(indexes)-set(points))
    
    points.append(closest_node(node,nodes))
print(points)
# Out:
# [(32, 81), (32, 82), (32, 83), (33, 84), (33, 85), (34, 86), (34, 87), (35, 88), (36, 89), (37, 89), (38, 90), (39, 91), (40, 92), (41, 92), (42, 93), (43, 94), (44, 95), (45, 95), (46, 96), (47, 97), (48, 97), (49, 97), (50, 97), (51, 97), (52, 97), (53, 97), (54, 97), (55, 96), (56, 96), (57, 96), (58, 96), (59, 96), (60, 95), (61, 95), (62, 94), (63, 93), (64, 92), (65, 92), (66, 91), (67, 91), (68, 90), (69, 90), (70, 89), (71, 89), (72, 88), (73, 88), (74, 87), (75, 87), (76, 87), (77, 86), (78, 86), (79, 85), (80, 84), (81, 83), (82, 83), (83, 82), (84, 82), (85, 81), (86, 80), (87, 79), (88, 79), (89, 78), (90, 78), (91, 77), (92, 77), (93, 76), (94, 76), (95, 75), (96, 74), (97, 74), (98, 74), (98, 73), (99, 72), (100, 72), (100, 71), (100, 73), (100, 74), (100, 75), (99, 76), (99, 77), (99, 78), (99, 79), (99, 80), (98, 81), (98, 82), (98, 83), (98, 84), (97, 85), (97, 86), (97, 87), (97, 88), (97, 89), (96, 90), (96, 91), (96, 92), (96, 93), (96, 94), (96, 95), (96, 96), (96, 97), (96, 98), (96, 99), (96, 100), (96, 101), (96, 102), (96, 103), (96, 104), (96, 105), (96, 106), (96, 107), (96, 108), (96, 109), (95, 110), (95, 111), (95, 112), (48, 66), (47, 66), (46, 67), (45, 67), (44, 68), (43, 68), (42, 69), (41, 70), (40, 70), (39, 71), (38, 72), (37, 73), (36, 74), (35, 75), (35, 76), (34, 77), (34, 78), (33, 79), (33, 80)]
